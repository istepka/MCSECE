# %% [markdown]
# # Case study
#
# In the case study we demonstrate how to generate counterfactual explanations by using our library on Statlog (German Credit Data) Data Set from UCI ML repository.

# %%
from tensorflow import keras
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
np.random.seed(44)

# %% [markdown]
# ### Data and model loading
#
# Statlog (German Credit Data) was gathered from UCI ML repository and consists of 20 features and 61 columns (most of them are represented by one-hot encoding). The dataset is wrapped in GermanData class, for easier use.
#
# Additionally, we load a pretrained keras model (simple logistic regression with 2 outputs) which will be used for prediction making.

# %%
from data import GermanData

german_data = GermanData('data/datasets/input_german.csv', 'data/datasets/labels_german.csv')
model = keras.models.load_model('models/model_german')

# %%
german_data.input.sample(5)
# Out:
#        duration  credit  installment_percent  residence_duration   age  \
# 99.0       20.0  7057.0                  3.0                 4.0  36.0
# 488.0      10.0  1418.0                  3.0                 2.0  35.0
# 206.0      12.0  1935.0                  4.0                 4.0  43.0
# 939.0      24.0  6842.0                  2.0                 4.0  46.0
# 729.0      24.0  1275.0                  2.0                 4.0  36.0
#
#        existing_credits  people_maintained  account_status_0..200 DM  \
# 99.0                2.0                2.0                       1.0
# 488.0               1.0                1.0                       0.0
# 206.0               3.0                1.0                       0.0
# 939.0               2.0                2.0                       0.0
# 729.0               2.0                1.0                       0.0
#
#        account_status_< 0 DM  account_status_>= 200 DM  ...  \
# 99.0                     0.0                       0.0  ...
# 488.0                    0.0                       0.0  ...
# 206.0                    0.0                       0.0  ...
# 939.0                    0.0                       0.0  ...
# 729.0                    0.0                       1.0  ...
#
#        job_unskilled - resident  phone_none  \
# 99.0                        0.0         0.0
# 488.0                       1.0         1.0
# 206.0                       0.0         0.0
# 939.0                       0.0         0.0
# 729.0                       0.0         0.0
#
#        phone_yes, registered under the customers name  foreign_no  \
# 99.0                                              1.0         0.0
# 488.0                                             0.0         1.0
# 206.0                                             1.0         0.0
# 939.0                                             1.0         0.0
# 729.0                                             1.0         0.0
#
#        foreign_yes  employment_1..4 years  employment_4..7 years  \
# 99.0           1.0                    0.0                    1.0
# 488.0          0.0                    1.0                    0.0
# 206.0          1.0                    0.0                    0.0
# 939.0          1.0                    1.0                    0.0
# 729.0          1.0                    1.0                    0.0
#
#        employment_< 1 year  employment_>= 7 years  employment_unemployed
# 99.0                   0.0                    0.0                    0.0
# 488.0                  0.0                    0.0                    0.0
# 206.0                  0.0                    1.0                    0.0
# 939.0                  0.0                    0.0                    0.0
# 729.0                  0.0                    0.0                    0.0
#
# [5 rows x 61 columns]

# %% [markdown]
# ### Test sample selection
#
# We select one instance, for which we want to calculate the counterfactual.

# %%
X_test = german_data.input.iloc[0]
X_test
# Out:
# duration                    6.0
# credit                   1169.0
# installment_percent         4.0
# residence_duration          4.0
# age                        67.0
#                           ...
# employment_1..4 years       0.0
# employment_4..7 years       0.0
# employment_< 1 year         0.0
# employment_>= 7 years       1.0
# employment_unemployed       0.0
# Name: 0.0, Length: 61, dtype: float64

# %% [markdown]
# ### Data scaling
#
# For the model to work, the dataset has to be standardized. The GermanData scale function uses StandardScaler from sklearn.

# %%
X_test_scaled = german_data.scale(X_test)
X_test_scaled
# Out:
# duration                 0.029412
# credit                   0.050567
# installment_percent      1.000000
# residence_duration       1.000000
# age                      0.857143
#                            ...
# employment_1..4 years    0.000000
# employment_4..7 years    0.000000
# employment_< 1 year      0.000000
# employment_>= 7 years    1.000000
# employment_unemployed    0.000000
# Length: 61, dtype: float64

# %% [markdown]
# Now, we evaluate the model on the test sample.

# %%
model.predict(np.expand_dims(X_test_scaled, axis=0))
# Out:
# 1/1 [==============================] - 0s 127ms/step
# array([[0.00939065, 0.9906094 ]], dtype=float32)

# %% [markdown]
# These outputs  are interpreted as the model prediction of the testing instance to class 1. For this credit data it means a bad (not paying loans) class of customers.

# %% [markdown]
# ### Counterfactual explanations generation
#
# Here we demonstrate how to generate counterfactual explanations using CADEX, FIMAP and ECE methods implemented in our library.

# %% [markdown]
# #### FIMAP

# %%
from cfec.explainers import Fimap

# %%
model_predictions = model.predict(german_data.X_train)
model_predictions = np.argmax(model_predictions, axis=1)
fimap = Fimap()
fimap.fit(german_data.X_train, model_predictions)

cf_fimap = fimap.generate(X_test)
# Out:
# 25/25 [==============================] - 0s 2ms/step
#
# Training s
# Training loss (for one batch): 0.2006
# Training accuracy 0.9198125
#
# Training g
# Training loss (for one batch): 0.9796
# Training accuracy 0.07875
# Training loss (for one batch): 0.9525
# Training accuracy 0.07875

# %%
model.predict(german_data.scale(cf_fimap))
# Out:
# 1/1 [==============================] - 0s 19ms/step
# array([[1., 0.]], dtype=float32)

# %% [markdown]
# The class predicted for the counterfactual is 0, meaning good credit score.

# %%
from cfec.visualization import show

show(X_test, cf_fimap)
# Out:
#                             X           X'     change
# duration                  6.0    -3.526000  -9.526000
# credit                 1169.0  1153.064941 -15.935059
# installment_percent       4.0   -50.490002 -54.490002
# residence_duration        4.0   -34.064999 -38.064999
# age                      67.0    -4.004000 -71.004000
# ...                       ...          ...        ...
# employment_1..4 years     0.0   -79.759003 -79.759003
# employment_4..7 years     0.0    -1.870000  -1.870000
# employment_< 1 year       0.0    48.715000  48.715000
# employment_>= 7 years     1.0   -61.115002 -62.115002
# employment_unemployed     0.0     3.482000   3.482000
#
# [61 rows x 3 columns]

# %% [markdown]
# We can see two things wrong with the generated counterfactual:
# - the categorical variables, originally represented in one-hot encoding, were changed to values different than 0 or 1
# - the value of age variable decreased, resulting in poor quality of the counterfactual - we can't recommend someone to decrease their age in order to obtain credit
#
# To fix it we can use constraints, which can be defined either in code or in spreadsheets (which can be used by users not familiar with programming).

# %%
from cfec.constraints import OneHot, ValueMonotonicity

constraints = [OneHot("account_status", 7, 10), 
               OneHot("credit_history", 11, 15),
               OneHot("purpose", 16, 25), 
               OneHot("savings", 26, 30), 
               OneHot("sex_status", 31, 34),
               OneHot("debtors", 35, 37), 
               OneHot("property", 38, 41),
               OneHot("other_installment_plans", 42, 44), 
               OneHot("housing", 45, 47), 
               OneHot("job", 48, 51),
               OneHot("phone", 52, 53), 
               OneHot("foreign", 54, 55), 
               OneHot("employment", 56, 60),
               ValueMonotonicity(['age'], "increasing")
              ]

# %%
fimap = Fimap(constraints=constraints, use_mapper=True)
fimap.fit(german_data.X_train, model_predictions)

cf_fimap_constraints = fimap.generate(X_test)
# Out:
# Continous columns: ['duration', 'credit', 'installment_percent', 'residence_duration', 'age', 'existing_credits', 'people_maintained', 'account_status_0..200 DM', 'account_status_< 0 DM', 'account_status_>= 200 DM', 'account_status_no checking account', 'credit_history_all credits at this bank paid back duly', 'credit_history_critical account', 'credit_history_delay in paying off in the past', 'credit_history_existing credits paid back duly till now', 'credit_history_no credits taken', 'purpose_business', 'purpose_car (new)', 'purpose_car (used)', 'purpose_domestic appliances', 'purpose_education', 'purpose_furniture/equipment', 'purpose_others', 'purpose_radio/television', 'purpose_repairs', 'purpose_retraining', 'savings_100..500 DM', 'savings_500..1000 DM', 'savings_< 100 DM', 'savings_>= 1000 DM', 'savings_unknown/ no savings account', 'sex_status_female: divorced/separated/married', 'sex_status_male: divorced/separated', 'sex_status_male: married/widowed', 'sex_status_male: single', 'debtors_co-applicant', 'debtors_guarantor', 'debtors_none', 'property_building society savings agreement', 'property_car or other, not in attribute 6', 'property_real estate', 'property_unknown / no property', 'other_installment_plans_bank', 'other_installment_plans_none', 'other_installment_plans_stores', 'housing_for free', 'housing_own', 'housing_rent', 'job_management/self-employed', 'job_skilled employee / official', 'job_unemployed/unskilled - non-resident', 'job_unskilled - resident', 'phone_none', 'phone_yes, registered under the customers name', 'foreign_no', 'foreign_yes', 'employment_1..4 years', 'employment_4..7 years', 'employment_< 1 year', 'employment_>= 7 years', 'employment_unemployed']
#
# Training s
# Training loss (for one batch): 0.1344
# Training accuracy 0.918175
#
# Training g
# Training loss (for one batch): 1.8724
# Training accuracy 0.07875
# Training loss (for one batch): 1.8489
# Training accuracy 0.07875

# %%
model.predict(german_data.scale(cf_fimap_constraints))
# Out:
# 1/1 [==============================] - 0s 20ms/step
# array([[1.000000e+00, 1.599048e-18]], dtype=float32)

# %% [markdown]
# As FIMAP is a method that doesn't guarantee finding a true counterfactual (with a change in prediction), we should always check whether the prediction changed. Here, we'd have to tune the hyperparameters to find a true counterfactual.

# %%
cf_fimap_constraints.squeeze()
# Out:
# duration                  128.459567
# credit                   1217.464041
# installment_percent       169.450522
# residence_duration        181.947724
# age                        67.000001
#                             ...
# employment_1..4 years       0.805302
# employment_4..7 years       0.172500
# employment_< 1 year         0.171250
# employment_>= 7 years       0.262500
# employment_unemployed       0.060000
# Name: 0, Length: 61, dtype: float64

# %%
# from cfec.visualization import show
# cf = cf_fimap_constraints.squeeze().round(3)
# x = X_test.round(3)
# df = pd.concat([x, cf.transpose()], axis=1)
# df.columns = ["X", "X'"]
# df["index"] = list(range(len(x)))
# df = df[df["X"] != df["X'"]]
# df["change"] = df["X'"] - df["X"]

# for constraint in constraints:
#     if isinstance(constraint, OneHot):
#         changed = df[df["index"].between(constraint.start_column, constraint.end_column)]
#         if len(changed) == 2:
#                 print(changed)
#                 value_original = changed["X"][changed["X"] == 1].index.tolist()[0]
#                 print(value_original)
#                 value_cf = changed["X'"][changed["X'"] == 1].index.tolist()[0]
#                 df.loc[constraint.name] = [value_original, value_cf, -1, value_cf, "OneHot"]
#                 df.drop(changed.index, inplace=True)

# %%
show(X_test, cf_fimap_constraints.squeeze(), constraints=constraints)
# Out:
#                                                          X        X'   change  \
# duration                                               6.0   128.460  122.460
# credit                                              1169.0  1217.464   48.464
# installment_percent                                    4.0   169.451  165.451
# residence_duration                                     4.0   181.948  177.948
# existing_credits                                       2.0   -48.084  -50.084
# people_maintained                                      1.0    88.019   87.019
# account_status_0..200 DM                               0.0     0.275    0.275
# account_status_< 0 DM                                  1.0     0.279   -0.721
# account_status_>= 200 DM                               0.0     0.068    0.068
# account_status_no checking account                     0.0     0.864    0.864
# credit_history_all credits at this bank paid ba...     0.0     0.055    0.055
# credit_history_critical account                        1.0     0.736   -0.264
# credit_history_delay in paying off in the past         0.0     0.088    0.088
# credit_history_existing credits paid back duly ...     0.0     0.528    0.528
# credit_history_no credits taken                        0.0     0.045    0.045
# purpose_business                                       0.0     0.099    0.099
# purpose_car (new)                                      0.0     0.641    0.641
# purpose_car (used)                                     0.0     0.102    0.102
# purpose_domestic appliances                            0.0     0.010    0.010
# purpose_education                                      0.0     0.051    0.051
# purpose_furniture/equipment                            0.0     0.188    0.188
# purpose_others                                         0.0     0.015    0.015
# purpose_radio/television                               1.0     0.278   -0.722
# purpose_repairs                                        0.0     0.024    0.024
# purpose_retraining                                     0.0     0.010    0.010
# savings_100..500 DM                                    0.0     0.112    0.112
# savings_500..1000 DM                                   0.0     0.312    0.312
# savings_< 100 DM                                       0.0     0.605    0.605
# savings_>= 1000 DM                                     0.0     0.048    0.048
# savings_unknown/ no savings account                    1.0     0.170   -0.830
# sex_status_female: divorced/separated/married          0.0     0.322    0.322
# sex_status_male: divorced/separated                    0.0     0.046    0.046
# sex_status_male: married/widowed                       0.0     0.391    0.391
# sex_status_male: single                                1.0     0.535   -0.465
# debtors_co-applicant                                   0.0     0.041    0.041
# debtors_guarantor                                      0.0     0.052    0.052
# debtors_none                                           1.0     1.198    0.198
# property_building society savings agreement            0.0     0.657    0.657
# property_car or other, not in attribute 6              0.0     0.334    0.334
# property_real estate                                   1.0     0.278   -0.722
# property_unknown / no property                         0.0     0.155    0.155
# other_installment_plans_bank                           0.0     0.149    0.149
# other_installment_plans_none                           1.0     1.201    0.201
# other_installment_plans_stores                         0.0     0.046    0.046
# housing_for free                                       0.0     0.108    0.108
# housing_own                                            1.0     1.158    0.158
# housing_rent                                           0.0     0.194    0.194
# job_management/self-employed                           0.0     0.154    0.154
# job_skilled employee / official                        1.0     0.622   -0.378
# job_unemployed/unskilled - non-resident                0.0     0.160    0.160
# job_unskilled - resident                               0.0     0.204    0.204
# phone_none                                             0.0     1.094    1.094
# phone_yes, registered under the customers name         1.0     0.395   -0.605
# foreign_no                                             0.0     0.232    0.232
# foreign_yes                                            1.0     0.961   -0.039
# employment_1..4 years                                  0.0     0.805    0.805
# employment_4..7 years                                  0.0     0.172    0.172
# employment_< 1 year                                    0.0     0.171    0.171
# employment_>= 7 years                                  1.0     0.262   -0.738
# employment_unemployed                                  0.0     0.060    0.060
#
#                                                    constraint
# duration
# credit
# installment_percent
# residence_duration
# existing_credits
# people_maintained
# account_status_0..200 DM
# account_status_< 0 DM
# account_status_>= 200 DM
# account_status_no checking account
# credit_history_all credits at this bank paid ba...
# credit_history_critical account
# credit_history_delay in paying off in the past
# credit_history_existing credits paid back duly ...
# credit_history_no credits taken
# purpose_business
# purpose_car (new)
# purpose_car (used)
# purpose_domestic appliances
# purpose_education
# purpose_furniture/equipment
# purpose_others
# purpose_radio/television
# purpose_repairs
# purpose_retraining
# savings_100..500 DM
# savings_500..1000 DM
# savings_< 100 DM
# savings_>= 1000 DM
# savings_unknown/ no savings account
# sex_status_female: divorced/separated/married
# sex_status_male: divorced/separated
# sex_status_male: married/widowed
# sex_status_male: single
# debtors_co-applicant
# debtors_guarantor
# debtors_none
# property_building society savings agreement
# property_car or other, not in attribute 6
# property_real estate
# property_unknown / no property
# other_installment_plans_bank
# other_installment_plans_none
# other_installment_plans_stores
# housing_for free
# housing_own
# housing_rent
# job_management/self-employed
# job_skilled employee / official
# job_unemployed/unskilled - non-resident
# job_unskilled - resident
# phone_none
# phone_yes, registered under the customers name
# foreign_no
# foreign_yes
# employment_1..4 years
# employment_4..7 years
# employment_< 1 year
# employment_>= 7 years
# employment_unemployed

# %%
X_test
# Out:
# duration                    6.0
# credit                   1169.0
# installment_percent         4.0
# residence_duration          4.0
# age                        67.0
#                           ...
# employment_1..4 years       0.0
# employment_4..7 years       0.0
# employment_< 1 year         0.0
# employment_>= 7 years       1.0
# employment_unemployed       0.0
# Name: 0.0, Length: 61, dtype: float64

# %% [markdown]
# The constraints column shows what constraints have been placed on the given attribute. If these constraints were not met, it would be marked with an asterisk.

# %% [markdown]
# #### CADEX
#
# For CADEX, we can either pass scaled instance and then unscale the obtained counterfactual or pass transform and inverse_transform parameters to the constructor.

# %%
from cfec.explainers import Cadex 

cadex = Cadex(model, transform=german_data.scale, inverse_transform=german_data.unscale, n_changed=10)
cf = cadex.generate(X_test)

# %%
model.predict(german_data.scale(cf))
# Out:
# 1/1 [==============================] - 0s 19ms/step
# array([[0.503318, 0.496682]], dtype=float32)

# %%
from cfec.visualization import show
show(X_test, cf)
# Out:
#                                                          X         X'  \
# credit                                              1169.0  13925.251
# account_status_no checking account                     0.0     -0.702
# credit_history_all credits at this bank paid ba...     0.0      0.702
# purpose_domestic appliances                            0.0     -0.702
# purpose_radio/television                               1.0      0.298
# savings_>= 1000 DM                                     0.0     -0.702
# savings_unknown/ no savings account                    1.0      0.298
# debtors_guarantor                                      0.0     -0.702
# property_real estate                                   1.0      0.298
# housing_own                                            1.0      0.298
#
#                                                        change
# credit                                              12756.251
# account_status_no checking account                     -0.702
# credit_history_all credits at this bank paid ba...      0.702
# purpose_domestic appliances                            -0.702
# purpose_radio/television                               -0.702
# savings_>= 1000 DM                                     -0.702
# savings_unknown/ no savings account                    -0.702
# debtors_guarantor                                      -0.702
# property_real estate                                   -0.702
# housing_own                                            -0.702

# %% [markdown]
# For CADEX we can also use constraints:

# %%
cadex = Cadex(model, n_changed=10, transform=german_data.scale, inverse_transform=german_data.unscale, constraints=constraints)
cf = cadex.generate(X_test)

# %%
model.predict(german_data.scale(cf))
# Out:
# 1/1 [==============================] - 0s 18ms/step
# array([[0.7723859 , 0.22761413]], dtype=float32)

# %%
show(X_test, cf, constraints=constraints)
# Out:
#                                                          X         X'  \
# credit                                              1169.0  10486.206
# existing_credits                                       2.0      0.462
# credit_history_all credits at this bank paid ba...     0.0      1.000
# credit_history_critical account                        1.0      0.000
# purpose_education                                      0.0      1.000
# purpose_radio/television                               1.0      0.000
# savings_100..500 DM                                    0.0      1.000
# savings_unknown/ no savings account                    1.0      0.000
# property_real estate                                   1.0      0.000
# property_unknown / no property                         0.0      1.000
# other_installment_plans_none                           1.0      0.000
# other_installment_plans_stores                         0.0      1.000
# housing_for free                                       0.0      1.000
# housing_own                                            1.0      0.000
#
#                                                       change constraint
# credit                                              9317.206
# existing_credits                                      -1.538
# credit_history_all credits at this bank paid ba...     1.000
# credit_history_critical account                       -1.000
# purpose_education                                      1.000
# purpose_radio/television                              -1.000
# savings_100..500 DM                                    1.000
# savings_unknown/ no savings account                   -1.000
# property_real estate                                  -1.000
# property_unknown / no property                         1.000
# other_installment_plans_none                          -1.000
# other_installment_plans_stores                         1.000
# housing_for free                                       1.000
# housing_own                                           -1.000

# %% [markdown]
# ### ECE
# We can use ECE to select the best counterfactuals - we'll run it using 10 explainers, 5 FIMAPs and 5 CADEXs with different parameter values.

# %%
fimaps = []
fimap_hyperparameters = [
    (0.1, 0.001, 0.01),
    (0.1, 0.05, 0.5),
    (0.2, 0.01, 0.1),
    (0.2, 0.08, 0.8),
    (0.5, 0.001, 0.01)
]
for tau, l1, l2 in fimap_hyperparameters:
    fimap = Fimap(tau, l1, l2)
    fimap.fit(german_data.X_train, model_predictions)
    fimaps.append(fimap)
    
cadexs = []
n_list = [5, 8, 10, 15, 20]
for n_changed in n_list:
    cadex = Cadex(model, n_changed, transform=german_data.scale, inverse_transform=german_data.unscale)
    cadexs.append(cadex)
# Out:
# Training s
# Training loss (for one batch): 0.1951
# Training accuracy 0.919525
#
# Training g
# Training loss (for one batch): 0.9731
# Training accuracy 0.07875
# Training loss (for one batch): 0.9462
# Training accuracy 0.07875
#
# Training s
# Training loss (for one batch): 0.1974
# Training accuracy 0.9197375
#
# Training g
# Training loss (for one batch): 2.2377
# Training accuracy 0.07875
# Training loss (for one batch): 2.2007
# Training accuracy 0.07875
#
# Training s
# Training loss (for one batch): 0.1977
# Training accuracy 0.9195875
#
# Training g
# Training loss (for one batch): 1.5174
# Training accuracy 0.07875
# Training loss (for one batch): 1.4765
# Training accuracy 0.07875
#
# Training s
# Training loss (for one batch): 0.1951
# Training accuracy 0.919825
#
# Training g
# Training loss (for one batch): 2.4546
# Training accuracy 0.07875
# Training loss (for one batch): 2.4246
# Training accuracy 0.07875
#
# Training s
# Training loss (for one batch): 0.1995
# Training accuracy 0.9197
#
# Training g
# Training loss (for one batch): 0.9715
# Training accuracy 0.07875
# Training loss (for one batch): 0.9476
# Training accuracy 0.07875

# %% [markdown]
# Now, let's use ECE and generate up to 4 best counterfactuals:

# %%
from cfec.explainers import ECE
from cfec.visualization import compare
pd.set_option("display.max_rows", None)

ece = ECE(10, columns=list(german_data.X_train.columns), bces=cadexs + fimaps, dist=2, h=5, lambda_=0.001, n_jobs=1)
cfs = ece.generate(X_test)

# %% [markdown]
# First, let's see all 10 counterfactuals:

# %%
compare(X_test, ece.get_aggregated_cfs())
# Out:
#                                                          X  CF1 change  \
# number of attributes changed                           0.0      61.000
# duration                                               6.0      -7.465
# credit                                              1169.0     -13.796
# installment_percent                                    4.0     -53.615
# residence_duration                                     4.0     -37.628
# age                                                   67.0     -71.805
# existing_credits                                       2.0     -60.345
# people_maintained                                      1.0      20.069
# account_status_0..200 DM                               0.0      -2.708
# account_status_< 0 DM                                  1.0      33.977
# account_status_>= 200 DM                               0.0     -57.894
# account_status_no checking account                     0.0    -149.229
# credit_history_all credits at this bank paid ba...     0.0      38.395
# credit_history_critical account                        1.0    -107.586
# credit_history_delay in paying off in the past         0.0     -36.488
# credit_history_existing credits paid back duly ...     0.0     -67.861
# credit_history_no credits taken                        0.0      48.307
# purpose_business                                       0.0      36.533
# purpose_car (new)                                      0.0     -10.579
# purpose_car (used)                                     0.0     -68.748
# purpose_domestic appliances                            0.0     -27.295
# purpose_education                                      0.0      85.695
# purpose_furniture/equipment                            0.0     -38.042
# purpose_others                                         0.0      56.899
# purpose_radio/television                               1.0    -145.158
# purpose_repairs                                        0.0       0.308
# purpose_retraining                                     0.0     -55.839
# savings_100..500 DM                                    0.0      47.495
# savings_500..1000 DM                                   0.0     -44.175
# savings_< 100 DM                                       0.0     -59.524
# savings_>= 1000 DM                                     0.0     -82.882
# savings_unknown/ no savings account                    1.0     -96.668
# sex_status_female: divorced/separated/married          0.0      12.031
# sex_status_male: divorced/separated                    0.0     -58.281
# sex_status_male: married/widowed                       0.0     -78.953
# sex_status_male: single                                1.0     -84.434
# debtors_co-applicant                                   0.0      26.341
# debtors_guarantor                                      0.0     -62.267
# debtors_none                                           1.0    -104.121
# property_building society savings agreement            0.0     -54.297
# property_car or other, not in attribute 6              0.0     -56.525
# property_real estate                                   1.0    -133.854
# property_unknown / no property                         0.0      69.052
# other_installment_plans_bank                           0.0     -20.953
# other_installment_plans_none                           1.0     -85.700
# other_installment_plans_stores                         0.0      -1.662
# housing_for free                                       0.0     121.540
# housing_own                                            1.0    -136.301
# housing_rent                                           0.0      36.184
# job_management/self-employed                           0.0     -38.701
# job_skilled employee / official                        1.0     -79.219
# job_unemployed/unskilled - non-resident                0.0     -70.338
# job_unskilled - resident                               0.0     -41.813
# phone_none                                             0.0     -79.557
# phone_yes, registered under the customers name         1.0    -111.320
# foreign_no                                             0.0     -82.090
# foreign_yes                                            1.0     -99.873
# employment_1..4 years                                  0.0     -77.891
# employment_4..7 years                                  0.0      -2.158
# employment_< 1 year                                    0.0      51.028
# employment_>= 7 years                                  1.0     -62.195
# employment_unemployed                                  0.0       2.998
#
#                                                     CF2 change  CF3 change  \
# number of attributes changed                            61.000      61.000
# duration                                                -6.399      -1.921
# credit                                                 -14.172     -20.289
# installment_percent                                    -51.894     -22.633
# residence_duration                                     -37.335     -13.889
# age                                                    -71.854     -52.091
# existing_credits                                       -62.533     -37.967
# people_maintained                                       20.074       4.628
# account_status_0..200 DM                                -0.230      -4.437
# account_status_< 0 DM                                   36.538      33.314
# account_status_>= 200 DM                               -57.762     -42.674
# account_status_no checking account                    -155.536    -104.655
# credit_history_all credits at this bank paid ba...      40.836      26.402
# credit_history_critical account                       -111.182     -65.597
# credit_history_delay in paying off in the past         -36.351     -18.114
# credit_history_existing credits paid back duly ...     -66.344     -29.757
# credit_history_no credits taken                         44.795      19.019
# purpose_business                                        34.943      22.247
# purpose_car (new)                                      -12.400      -0.498
# purpose_car (used)                                     -65.487     -48.052
# purpose_domestic appliances                            -27.283     -18.677
# purpose_education                                       87.945      45.889
# purpose_furniture/equipment                            -39.459     -25.320
# purpose_others                                          57.391      38.437
# purpose_radio/television                              -147.039     -91.815
# purpose_repairs                                          3.557     -11.495
# purpose_retraining                                     -57.403     -42.151
# savings_100..500 DM                                     44.872       9.174
# savings_500..1000 DM                                   -45.283     -36.514
# savings_< 100 DM                                       -60.783     -27.456
# savings_>= 1000 DM                                     -85.193     -58.120
# savings_unknown/ no savings account                    -97.475     -68.189
# sex_status_female: divorced/separated/married           12.952       5.753
# sex_status_male: divorced/separated                    -59.935     -34.065
# sex_status_male: married/widowed                       -79.825     -50.739
# sex_status_male: single                                -84.192     -57.623
# debtors_co-applicant                                    25.028      28.765
# debtors_guarantor                                      -64.355     -39.621
# debtors_none                                          -105.275     -53.448
# property_building society savings agreement            -56.796     -21.810
# property_car or other, not in attribute 6              -55.884     -35.137
# property_real estate                                  -137.850     -84.144
# property_unknown / no property                          71.259      46.102
# other_installment_plans_bank                           -21.449     -11.146
# other_installment_plans_none                           -85.560     -46.089
# other_installment_plans_stores                          -1.931       6.137
# housing_for free                                       124.652      78.867
# housing_own                                           -137.006     -95.674
# housing_rent                                            39.140      22.495
# job_management/self-employed                           -38.437     -18.625
# job_skilled employee / official                        -79.492     -46.357
# job_unemployed/unskilled - non-resident                -69.421     -54.533
# job_unskilled - resident                               -44.915     -25.743
# phone_none                                             -77.556     -36.507
# phone_yes, registered under the customers name        -112.417     -62.701
# foreign_no                                             -84.014     -58.948
# foreign_yes                                           -102.707     -52.070
# employment_1..4 years                                  -79.382     -54.791
# employment_4..7 years                                   -0.794     -10.190
# employment_< 1 year                                     53.352      21.112
# employment_>= 7 years                                  -61.515     -50.661
# employment_unemployed                                    2.450      11.681
#
#                                                     CF4 change CF5 change  \
# number of attributes changed                            61.000        5.0
# duration                                                -0.011          -
# credit                                                  -9.211          -
# installment_percent                                     -6.486          -
# residence_duration                                      -1.391          -
# age                                                    -20.988          -
# existing_credits                                       -17.314          -
# people_maintained                                        2.439          -
# account_status_0..200 DM                                 1.222          -
# account_status_< 0 DM                                   17.500          -
# account_status_>= 200 DM                               -20.285          -
# account_status_no checking account                     -45.396     -1.263
# credit_history_all credits at this bank paid ba...      15.021          -
# credit_history_critical account                        -24.680          -
# credit_history_delay in paying off in the past          -8.715          -
# credit_history_existing credits paid back duly ...      -8.693          -
# credit_history_no credits taken                         11.316          -
# purpose_business                                         6.248          -
# purpose_car (new)                                        0.502          -
# purpose_car (used)                                     -23.256          -
# purpose_domestic appliances                            -11.409          -
# purpose_education                                       22.161          -
# purpose_furniture/equipment                            -10.205          -
# purpose_others                                          16.100          -
# purpose_radio/television                               -37.965     -1.263
# purpose_repairs                                         -8.422          -
# purpose_retraining                                     -21.214          -
# savings_100..500 DM                                      1.708          -
# savings_500..1000 DM                                   -20.953          -
# savings_< 100 DM                                        -7.889          -
# savings_>= 1000 DM                                     -25.827          -
# savings_unknown/ no savings account                    -32.060     -1.263
# sex_status_female: divorced/separated/married            1.609          -
# sex_status_male: divorced/separated                    -16.248          -
# sex_status_male: married/widowed                       -24.714          -
# sex_status_male: single                                -23.770          -
# debtors_co-applicant                                    11.291          -
# debtors_guarantor                                      -19.341     -1.263
# debtors_none                                           -17.979          -
# property_building society savings agreement             -7.671          -
# property_car or other, not in attribute 6              -14.538          -
# property_real estate                                   -37.591          -
# property_unknown / no property                          21.605          -
# other_installment_plans_bank                            -5.585          -
# other_installment_plans_none                           -16.271          -
# other_installment_plans_stores                           5.992          -
# housing_for free                                        34.129          -
# housing_own                                            -41.406     -1.263
# housing_rent                                            13.077          -
# job_management/self-employed                            -8.292          -
# job_skilled employee / official                        -19.115          -
# job_unemployed/unskilled - non-resident                -27.288          -
# job_unskilled - resident                               -10.117          -
# phone_none                                             -12.117          -
# phone_yes, registered under the customers name         -20.775          -
# foreign_no                                             -27.657          -
# foreign_yes                                            -19.468          -
# employment_1..4 years                                  -21.246          -
# employment_4..7 years                                   -5.613          -
# employment_< 1 year                                      7.257          -
# employment_>= 7 years                                  -22.606          -
# employment_unemployed                                    8.756          -
#
#                                                    CF6 change CF7 change  \
# number of attributes changed                              8.0       15.0
# duration                                                    -          -
# credit                                                      -   9630.301
# installment_percent                                         -          -
# residence_duration                                          -          -
# age                                                         -          -
# existing_credits                                            -      -1.59
# people_maintained                                           -          -
# account_status_0..200 DM                                    -          -
# account_status_< 0 DM                                       -          -
# account_status_>= 200 DM                                    -          -
# account_status_no checking account                     -0.854      -0.53
# credit_history_all credits at this bank paid ba...          -       0.53
# credit_history_critical account                             -          -
# credit_history_delay in paying off in the past              -          -
# credit_history_existing credits paid back duly ...          -          -
# credit_history_no credits taken                             -          -
# purpose_business                                            -          -
# purpose_car (new)                                           -          -
# purpose_car (used)                                          -      -0.53
# purpose_domestic appliances                            -0.854      -0.53
# purpose_education                                           -          -
# purpose_furniture/equipment                                 -          -
# purpose_others                                              -          -
# purpose_radio/television                               -0.854      -0.53
# purpose_repairs                                             -          -
# purpose_retraining                                          -      -0.53
# savings_100..500 DM                                         -          -
# savings_500..1000 DM                                        -          -
# savings_< 100 DM                                            -          -
# savings_>= 1000 DM                                     -0.854      -0.53
# savings_unknown/ no savings account                    -0.854      -0.53
# sex_status_female: divorced/separated/married               -          -
# sex_status_male: divorced/separated                         -          -
# sex_status_male: married/widowed                            -          -
# sex_status_male: single                                     -          -
# debtors_co-applicant                                        -          -
# debtors_guarantor                                      -0.854      -0.53
# debtors_none                                                -          -
# property_building society savings agreement                 -          -
# property_car or other, not in attribute 6                   -          -
# property_real estate                                   -0.854      -0.53
# property_unknown / no property                              -          -
# other_installment_plans_bank                                -          -
# other_installment_plans_none                                -          -
# other_installment_plans_stores                              -       0.53
# housing_for free                                            -          -
# housing_own                                            -0.854      -0.53
# housing_rent                                                -          -
# job_management/self-employed                                -          -
# job_skilled employee / official                             -          -
# job_unemployed/unskilled - non-resident                     -          -
# job_unskilled - resident                                    -          -
# phone_none                                                  -          -
# phone_yes, registered under the customers name              -          -
# foreign_no                                                  -      -0.53
# foreign_yes                                                 -          -
# employment_1..4 years                                       -          -
# employment_4..7 years                                       -          -
# employment_< 1 year                                         -          -
# employment_>= 7 years                                       -          -
# employment_unemployed                                       -          -
#
#                                                    CF8 change  CF9 change  \
# number of attributes changed                             10.0      61.000
# duration                                                    -       0.017
# credit                                              13107.152      -6.172
# installment_percent                                         -      -4.531
# residence_duration                                          -      -0.516
# age                                                         -     -13.798
# existing_credits                                            -     -11.804
# people_maintained                                           -       1.276
# account_status_0..200 DM                                    -       1.108
# account_status_< 0 DM                                       -      12.944
# account_status_>= 200 DM                                    -     -13.956
# account_status_no checking account                     -0.721     -30.426
# credit_history_all credits at this bank paid ba...      0.721      10.504
# credit_history_critical account                             -     -16.812
# credit_history_delay in paying off in the past              -      -6.643
# credit_history_existing credits paid back duly ...          -      -5.614
# credit_history_no credits taken                             -       7.859
# purpose_business                                            -       3.494
# purpose_car (new)                                           -       0.813
# purpose_car (used)                                          -     -15.775
# purpose_domestic appliances                            -0.721      -8.550
# purpose_education                                           -      14.517
# purpose_furniture/equipment                                 -      -6.709
# purpose_others                                              -      11.049
# purpose_radio/television                               -0.721     -25.882
# purpose_repairs                                             -      -5.660
# purpose_retraining                                          -     -15.934
# savings_100..500 DM                                         -       0.899
# savings_500..1000 DM                                        -     -15.456
# savings_< 100 DM                                            -      -4.262
# savings_>= 1000 DM                                     -0.721     -17.359
# savings_unknown/ no savings account                    -0.721     -22.394
# sex_status_female: divorced/separated/married               -       0.649
# sex_status_male: divorced/separated                         -     -11.796
# sex_status_male: married/widowed                            -     -16.961
# sex_status_male: single                                     -     -16.272
# debtors_co-applicant                                        -       7.399
# debtors_guarantor                                      -0.721     -13.992
# debtors_none                                                -     -10.852
# property_building society savings agreement                 -      -5.044
# property_car or other, not in attribute 6                   -      -9.926
# property_real estate                                   -0.721     -25.164
# property_unknown / no property                              -      14.753
# other_installment_plans_bank                                -      -3.416
# other_installment_plans_none                                -     -10.059
# other_installment_plans_stores                              -       4.187
# housing_for free                                            -      22.936
# housing_own                                            -0.721     -27.941
# housing_rent                                                -       8.924
# job_management/self-employed                                -      -5.621
# job_skilled employee / official                             -     -12.605
# job_unemployed/unskilled - non-resident                     -     -19.954
# job_unskilled - resident                                    -      -7.130
# phone_none                                                  -      -8.004
# phone_yes, registered under the customers name              -     -13.783
# foreign_no                                                  -     -19.732
# foreign_yes                                                 -     -12.886
# employment_1..4 years                                       -     -14.108
# employment_4..7 years                                       -      -4.034
# employment_< 1 year                                         -       4.284
# employment_>= 7 years                                       -     -15.511
# employment_unemployed                                       -       6.336
#
#                                                    CF10 change constraint
# number of attributes changed                              20.0
# duration                                                29.097
# credit                                                7776.556
# installment_percent                                          -
# residence_duration                                           -
# age                                                          -
# existing_credits                                        -1.284
# people_maintained                                            -
# account_status_0..200 DM                                     -
# account_status_< 0 DM                                    0.428
# account_status_>= 200 DM                                     -
# account_status_no checking account                      -0.428
# credit_history_all credits at this bank paid ba...       0.428
# credit_history_critical account                              -
# credit_history_delay in paying off in the past               -
# credit_history_existing credits paid back duly ...           -
# credit_history_no credits taken                          0.428
# purpose_business                                             -
# purpose_car (new)                                            -
# purpose_car (used)                                      -0.428
# purpose_domestic appliances                             -0.428
# purpose_education                                        0.428
# purpose_furniture/equipment                                  -
# purpose_others                                               -
# purpose_radio/television                                -0.428
# purpose_repairs                                              -
# purpose_retraining                                      -0.428
# savings_100..500 DM                                          -
# savings_500..1000 DM                                         -
# savings_< 100 DM                                             -
# savings_>= 1000 DM                                      -0.428
# savings_unknown/ no savings account                     -0.428
# sex_status_female: divorced/separated/married                -
# sex_status_male: divorced/separated                          -
# sex_status_male: married/widowed                             -
# sex_status_male: single                                 -0.428
# debtors_co-applicant                                         -
# debtors_guarantor                                       -0.428
# debtors_none                                                 -
# property_building society savings agreement                  -
# property_car or other, not in attribute 6                    -
# property_real estate                                    -0.428
# property_unknown / no property                               -
# other_installment_plans_bank                                 -
# other_installment_plans_none                                 -
# other_installment_plans_stores                           0.428
# housing_for free                                             -
# housing_own                                             -0.428
# housing_rent                                                 -
# job_management/self-employed                                 -
# job_skilled employee / official                              -
# job_unemployed/unskilled - non-resident                      -
# job_unskilled - resident                                     -
# phone_none                                                   -
# phone_yes, registered under the customers name               -
# foreign_no                                              -0.428
# foreign_yes                                                  -
# employment_1..4 years                                        -
# employment_4..7 years                                        -
# employment_< 1 year                                          -
# employment_>= 7 years                                        -
# employment_unemployed                                        -

# %% [markdown]
# And now, those selected by ECE:

# %%
compare(X_test, cfs)
# Out:
#                                                          X CF1 change  \
# number of attributes changed                           0.0       15.0
# duration                                               6.0          -
# credit                                              1169.0   9630.301
# installment_percent                                    4.0          -
# residence_duration                                     4.0          -
# age                                                   67.0          -
# existing_credits                                       2.0      -1.59
# people_maintained                                      1.0          -
# account_status_0..200 DM                               0.0          -
# account_status_< 0 DM                                  1.0          -
# account_status_>= 200 DM                               0.0          -
# account_status_no checking account                     0.0      -0.53
# credit_history_all credits at this bank paid ba...     0.0       0.53
# credit_history_critical account                        1.0          -
# credit_history_delay in paying off in the past         0.0          -
# credit_history_existing credits paid back duly ...     0.0          -
# credit_history_no credits taken                        0.0          -
# purpose_business                                       0.0          -
# purpose_car (new)                                      0.0          -
# purpose_car (used)                                     0.0      -0.53
# purpose_domestic appliances                            0.0      -0.53
# purpose_education                                      0.0          -
# purpose_furniture/equipment                            0.0          -
# purpose_others                                         0.0          -
# purpose_radio/television                               1.0      -0.53
# purpose_repairs                                        0.0          -
# purpose_retraining                                     0.0      -0.53
# savings_100..500 DM                                    0.0          -
# savings_500..1000 DM                                   0.0          -
# savings_< 100 DM                                       0.0          -
# savings_>= 1000 DM                                     0.0      -0.53
# savings_unknown/ no savings account                    1.0      -0.53
# sex_status_female: divorced/separated/married          0.0          -
# sex_status_male: divorced/separated                    0.0          -
# sex_status_male: married/widowed                       0.0          -
# sex_status_male: single                                1.0          -
# debtors_co-applicant                                   0.0          -
# debtors_guarantor                                      0.0      -0.53
# debtors_none                                           1.0          -
# property_building society savings agreement            0.0          -
# property_car or other, not in attribute 6              0.0          -
# property_real estate                                   1.0      -0.53
# property_unknown / no property                         0.0          -
# other_installment_plans_bank                           0.0          -
# other_installment_plans_none                           1.0          -
# other_installment_plans_stores                         0.0       0.53
# housing_for free                                       0.0          -
# housing_own                                            1.0      -0.53
# housing_rent                                           0.0          -
# job_management/self-employed                           0.0          -
# job_skilled employee / official                        1.0          -
# job_unemployed/unskilled - non-resident                0.0          -
# job_unskilled - resident                               0.0          -
# phone_none                                             0.0          -
# phone_yes, registered under the customers name         1.0          -
# foreign_no                                             0.0      -0.53
# foreign_yes                                            1.0          -
# employment_1..4 years                                  0.0          -
# employment_4..7 years                                  0.0          -
# employment_< 1 year                                    0.0          -
# employment_>= 7 years                                  1.0          -
# employment_unemployed                                  0.0          -
#
#                                                    CF2 change constraint
# number of attributes changed                             10.0
# duration                                                    -
# credit                                              13107.152
# installment_percent                                         -
# residence_duration                                          -
# age                                                         -
# existing_credits                                            -
# people_maintained                                           -
# account_status_0..200 DM                                    -
# account_status_< 0 DM                                       -
# account_status_>= 200 DM                                    -
# account_status_no checking account                     -0.721
# credit_history_all credits at this bank paid ba...      0.721
# credit_history_critical account                             -
# credit_history_delay in paying off in the past              -
# credit_history_existing credits paid back duly ...          -
# credit_history_no credits taken                             -
# purpose_business                                            -
# purpose_car (new)                                           -
# purpose_car (used)                                          -
# purpose_domestic appliances                            -0.721
# purpose_education                                           -
# purpose_furniture/equipment                                 -
# purpose_others                                              -
# purpose_radio/television                               -0.721
# purpose_repairs                                             -
# purpose_retraining                                          -
# savings_100..500 DM                                         -
# savings_500..1000 DM                                        -
# savings_< 100 DM                                            -
# savings_>= 1000 DM                                     -0.721
# savings_unknown/ no savings account                    -0.721
# sex_status_female: divorced/separated/married               -
# sex_status_male: divorced/separated                         -
# sex_status_male: married/widowed                            -
# sex_status_male: single                                     -
# debtors_co-applicant                                        -
# debtors_guarantor                                      -0.721
# debtors_none                                                -
# property_building society savings agreement                 -
# property_car or other, not in attribute 6                   -
# property_real estate                                   -0.721
# property_unknown / no property                              -
# other_installment_plans_bank                                -
# other_installment_plans_none                                -
# other_installment_plans_stores                              -
# housing_for free                                            -
# housing_own                                            -0.721
# housing_rent                                                -
# job_management/self-employed                                -
# job_skilled employee / official                             -
# job_unemployed/unskilled - non-resident                     -
# job_unskilled - resident                                    -
# phone_none                                                  -
# phone_yes, registered under the customers name              -
# foreign_no                                                  -
# foreign_yes                                                 -
# employment_1..4 years                                       -
# employment_4..7 years                                       -
# employment_< 1 year                                         -
# employment_>= 7 years                                       -
# employment_unemployed                                       -

# %% [markdown]
# We can do the same with constraints:

# %%
fimaps = []
fimap_hyperparameters = [
    (0.1, 0.001, 0.01),
    (0.1, 0.05, 0.5),
    (0.2, 0.01, 0.1),
    (0.2, 0.08, 0.8),
    (0.5, 0.001, 0.01)
]
for tau, l1, l2 in fimap_hyperparameters:
    fimap = Fimap(tau, l1, l2, constraints=constraints, use_mapper=True)
    fimap.fit(german_data.X_train, model_predictions)
    fimaps.append(fimap)
    
cadexs = []
n_list = [10, 14, 18, 20, 25]
for n_changed in n_list:
    cadex = Cadex(model, n_changed, transform=german_data.scale, inverse_transform=german_data.unscale, constraints=constraints)
    cadexs.append(cadex)
# Out:
# Continous columns: ['duration', 'credit', 'installment_percent', 'residence_duration', 'age', 'existing_credits', 'people_maintained', 'account_status_0..200 DM', 'account_status_< 0 DM', 'account_status_>= 200 DM', 'account_status_no checking account', 'credit_history_all credits at this bank paid back duly', 'credit_history_critical account', 'credit_history_delay in paying off in the past', 'credit_history_existing credits paid back duly till now', 'credit_history_no credits taken', 'purpose_business', 'purpose_car (new)', 'purpose_car (used)', 'purpose_domestic appliances', 'purpose_education', 'purpose_furniture/equipment', 'purpose_others', 'purpose_radio/television', 'purpose_repairs', 'purpose_retraining', 'savings_100..500 DM', 'savings_500..1000 DM', 'savings_< 100 DM', 'savings_>= 1000 DM', 'savings_unknown/ no savings account', 'sex_status_female: divorced/separated/married', 'sex_status_male: divorced/separated', 'sex_status_male: married/widowed', 'sex_status_male: single', 'debtors_co-applicant', 'debtors_guarantor', 'debtors_none', 'property_building society savings agreement', 'property_car or other, not in attribute 6', 'property_real estate', 'property_unknown / no property', 'other_installment_plans_bank', 'other_installment_plans_none', 'other_installment_plans_stores', 'housing_for free', 'housing_own', 'housing_rent', 'job_management/self-employed', 'job_skilled employee / official', 'job_unemployed/unskilled - non-resident', 'job_unskilled - resident', 'phone_none', 'phone_yes, registered under the customers name', 'foreign_no', 'foreign_yes', 'employment_1..4 years', 'employment_4..7 years', 'employment_< 1 year', 'employment_>= 7 years', 'employment_unemployed']
#
# Training s
# Training loss (for one batch): 0.1355
# Training accuracy 0.9182
#
# Training g
# Training loss (for one batch): 1.8986
# Training accuracy 0.07875
# Training loss (for one batch): 1.8845
# Training accuracy 0.07875
# Continous columns: ['duration', 'credit', 'installment_percent', 'residence_duration', 'age', 'existing_credits', 'people_maintained', 'account_status_0..200 DM', 'account_status_< 0 DM', 'account_status_>= 200 DM', 'account_status_no checking account', 'credit_history_all credits at this bank paid back duly', 'credit_history_critical account', 'credit_history_delay in paying off in the past', 'credit_history_existing credits paid back duly till now', 'credit_history_no credits taken', 'purpose_business', 'purpose_car (new)', 'purpose_car (used)', 'purpose_domestic appliances', 'purpose_education', 'purpose_furniture/equipment', 'purpose_others', 'purpose_radio/television', 'purpose_repairs', 'purpose_retraining', 'savings_100..500 DM', 'savings_500..1000 DM', 'savings_< 100 DM', 'savings_>= 1000 DM', 'savings_unknown/ no savings account', 'sex_status_female: divorced/separated/married', 'sex_status_male: divorced/separated', 'sex_status_male: married/widowed', 'sex_status_male: single', 'debtors_co-applicant', 'debtors_guarantor', 'debtors_none', 'property_building society savings agreement', 'property_car or other, not in attribute 6', 'property_real estate', 'property_unknown / no property', 'other_installment_plans_bank', 'other_installment_plans_none', 'other_installment_plans_stores', 'housing_for free', 'housing_own', 'housing_rent', 'job_management/self-employed', 'job_skilled employee / official', 'job_unemployed/unskilled - non-resident', 'job_unskilled - resident', 'phone_none', 'phone_yes, registered under the customers name', 'foreign_no', 'foreign_yes', 'employment_1..4 years', 'employment_4..7 years', 'employment_< 1 year', 'employment_>= 7 years', 'employment_unemployed']
#
# Training s
# Training loss (for one batch): 0.1347
# Training accuracy 0.918175
#
# Training g
# Training loss (for one batch): 2.3758
# Training accuracy 0.07875
# Training loss (for one batch): 2.3479
# Training accuracy 0.07875
# Continous columns: ['duration', 'credit', 'installment_percent', 'residence_duration', 'age', 'existing_credits', 'people_maintained', 'account_status_0..200 DM', 'account_status_< 0 DM', 'account_status_>= 200 DM', 'account_status_no checking account', 'credit_history_all credits at this bank paid back duly', 'credit_history_critical account', 'credit_history_delay in paying off in the past', 'credit_history_existing credits paid back duly till now', 'credit_history_no credits taken', 'purpose_business', 'purpose_car (new)', 'purpose_car (used)', 'purpose_domestic appliances', 'purpose_education', 'purpose_furniture/equipment', 'purpose_others', 'purpose_radio/television', 'purpose_repairs', 'purpose_retraining', 'savings_100..500 DM', 'savings_500..1000 DM', 'savings_< 100 DM', 'savings_>= 1000 DM', 'savings_unknown/ no savings account', 'sex_status_female: divorced/separated/married', 'sex_status_male: divorced/separated', 'sex_status_male: married/widowed', 'sex_status_male: single', 'debtors_co-applicant', 'debtors_guarantor', 'debtors_none', 'property_building society savings agreement', 'property_car or other, not in attribute 6', 'property_real estate', 'property_unknown / no property', 'other_installment_plans_bank', 'other_installment_plans_none', 'other_installment_plans_stores', 'housing_for free', 'housing_own', 'housing_rent', 'job_management/self-employed', 'job_skilled employee / official', 'job_unemployed/unskilled - non-resident', 'job_unskilled - resident', 'phone_none', 'phone_yes, registered under the customers name', 'foreign_no', 'foreign_yes', 'employment_1..4 years', 'employment_4..7 years', 'employment_< 1 year', 'employment_>= 7 years', 'employment_unemployed']
#
# Training s
# Training loss (for one batch): 0.1368
# Training accuracy 0.91845
#
# Training g
# Training loss (for one batch): 2.0881
# Training accuracy 0.07875
# Training loss (for one batch): 2.1046
# Training accuracy 0.07875
# Continous columns: ['duration', 'credit', 'installment_percent', 'residence_duration', 'age', 'existing_credits', 'people_maintained', 'account_status_0..200 DM', 'account_status_< 0 DM', 'account_status_>= 200 DM', 'account_status_no checking account', 'credit_history_all credits at this bank paid back duly', 'credit_history_critical account', 'credit_history_delay in paying off in the past', 'credit_history_existing credits paid back duly till now', 'credit_history_no credits taken', 'purpose_business', 'purpose_car (new)', 'purpose_car (used)', 'purpose_domestic appliances', 'purpose_education', 'purpose_furniture/equipment', 'purpose_others', 'purpose_radio/television', 'purpose_repairs', 'purpose_retraining', 'savings_100..500 DM', 'savings_500..1000 DM', 'savings_< 100 DM', 'savings_>= 1000 DM', 'savings_unknown/ no savings account', 'sex_status_female: divorced/separated/married', 'sex_status_male: divorced/separated', 'sex_status_male: married/widowed', 'sex_status_male: single', 'debtors_co-applicant', 'debtors_guarantor', 'debtors_none', 'property_building society savings agreement', 'property_car or other, not in attribute 6', 'property_real estate', 'property_unknown / no property', 'other_installment_plans_bank', 'other_installment_plans_none', 'other_installment_plans_stores', 'housing_for free', 'housing_own', 'housing_rent', 'job_management/self-employed', 'job_skilled employee / official', 'job_unemployed/unskilled - non-resident', 'job_unskilled - resident', 'phone_none', 'phone_yes, registered under the customers name', 'foreign_no', 'foreign_yes', 'employment_1..4 years', 'employment_4..7 years', 'employment_< 1 year', 'employment_>= 7 years', 'employment_unemployed']
#
# Training s
# Training loss (for one batch): 0.1365
# Training accuracy 0.9185375
#
# Training g
# Training loss (for one batch): 2.5090
# Training accuracy 0.07875
# Training loss (for one batch): 2.4945
# Training accuracy 0.07875
# Continous columns: ['duration', 'credit', 'installment_percent', 'residence_duration', 'age', 'existing_credits', 'people_maintained', 'account_status_0..200 DM', 'account_status_< 0 DM', 'account_status_>= 200 DM', 'account_status_no checking account', 'credit_history_all credits at this bank paid back duly', 'credit_history_critical account', 'credit_history_delay in paying off in the past', 'credit_history_existing credits paid back duly till now', 'credit_history_no credits taken', 'purpose_business', 'purpose_car (new)', 'purpose_car (used)', 'purpose_domestic appliances', 'purpose_education', 'purpose_furniture/equipment', 'purpose_others', 'purpose_radio/television', 'purpose_repairs', 'purpose_retraining', 'savings_100..500 DM', 'savings_500..1000 DM', 'savings_< 100 DM', 'savings_>= 1000 DM', 'savings_unknown/ no savings account', 'sex_status_female: divorced/separated/married', 'sex_status_male: divorced/separated', 'sex_status_male: married/widowed', 'sex_status_male: single', 'debtors_co-applicant', 'debtors_guarantor', 'debtors_none', 'property_building society savings agreement', 'property_car or other, not in attribute 6', 'property_real estate', 'property_unknown / no property', 'other_installment_plans_bank', 'other_installment_plans_none', 'other_installment_plans_stores', 'housing_for free', 'housing_own', 'housing_rent', 'job_management/self-employed', 'job_skilled employee / official', 'job_unemployed/unskilled - non-resident', 'job_unskilled - resident', 'phone_none', 'phone_yes, registered under the customers name', 'foreign_no', 'foreign_yes', 'employment_1..4 years', 'employment_4..7 years', 'employment_< 1 year', 'employment_>= 7 years', 'employment_unemployed']
#
# Training s
# Training loss (for one batch): 0.1378
# Training accuracy 0.9180875
#
# Training g
# Training loss (for one batch): 1.8801
# Training accuracy 0.07875
# Training loss (for one batch): 1.8661
# Training accuracy 0.07875

# %%
ece = ECE(4, columns=list(german_data.X_train.columns), bces=cadexs + fimaps, dist=2, h=5, lambda_=0.001, n_jobs=1)
cfs = ece.generate(X_test)

# %%
compare(X_test, ece.get_aggregated_cfs(), constraints=constraints)
# Out:
#                                                          X CF1 change  \
# number of attributes changed                           0.0       10.0
# duration                                               6.0          -
# credit                                              1169.0   9305.086
# installment_percent                                    4.0          -
# residence_duration                                     4.0          -
# age                                                   67.0          -
# existing_credits                                       2.0     -1.536
# people_maintained                                      1.0          -
# account_status_0..200 DM                               0.0          -
# account_status_< 0 DM                                  1.0          -
# account_status_>= 200 DM                               0.0          -
# account_status_no checking account                     0.0          -
# credit_history_all credits at this bank paid ba...     0.0        1.0
# credit_history_critical account                        1.0       -1.0
# credit_history_delay in paying off in the past         0.0          -
# credit_history_existing credits paid back duly ...     0.0          -
# credit_history_no credits taken                        0.0          -
# purpose_business                                       0.0          -
# purpose_car (new)                                      0.0          -
# purpose_car (used)                                     0.0          -
# purpose_domestic appliances                            0.0          -
# purpose_education                                      0.0        1.0
# purpose_furniture/equipment                            0.0          -
# purpose_others                                         0.0          -
# purpose_radio/television                               1.0       -1.0
# purpose_repairs                                        0.0          -
# purpose_retraining                                     0.0          -
# savings_100..500 DM                                    0.0        1.0
# savings_500..1000 DM                                   0.0          -
# savings_< 100 DM                                       0.0          -
# savings_>= 1000 DM                                     0.0          -
# savings_unknown/ no savings account                    1.0       -1.0
# sex_status_female: divorced/separated/married          0.0          -
# sex_status_male: divorced/separated                    0.0          -
# sex_status_male: married/widowed                       0.0          -
# sex_status_male: single                                1.0          -
# debtors_co-applicant                                   0.0          -
# debtors_guarantor                                      0.0          -
# debtors_none                                           1.0          -
# property_building society savings agreement            0.0          -
# property_car or other, not in attribute 6              0.0          -
# property_real estate                                   1.0       -1.0
# property_unknown / no property                         0.0        1.0
# other_installment_plans_bank                           0.0          -
# other_installment_plans_none                           1.0       -1.0
# other_installment_plans_stores                         0.0        1.0
# housing_for free                                       0.0        1.0
# housing_own                                            1.0       -1.0
# housing_rent                                           0.0          -
# job_management/self-employed                           0.0          -
# job_skilled employee / official                        1.0          -
# job_unemployed/unskilled - non-resident                0.0          -
# job_unskilled - resident                               0.0          -
# phone_none                                             0.0          -
# phone_yes, registered under the customers name         1.0          -
# foreign_no                                             0.0          -
# foreign_yes                                            1.0          -
# employment_1..4 years                                  0.0          -
# employment_4..7 years                                  0.0          -
# employment_< 1 year                                    0.0          -
# employment_>= 7 years                                  1.0          -
# employment_unemployed                                  0.0          -
#
#                                                    CF2 change CF3 change  \
# number of attributes changed                             37.0       37.0
# duration                                                1.807      3.716
# credit                                                 -5.741     -7.601
# installment_percent                                    22.442     35.027
# residence_duration                                     18.854     31.135
# age                                                         -          -
# existing_credits                                       -5.493     -8.498
# people_maintained                                      13.841     22.899
# account_status_0..200 DM                                0.275      0.275
# account_status_< 0 DM                                  -0.721     -0.721
# account_status_>= 200 DM                                0.318      0.318
# account_status_no checking account                      0.379      0.379
# credit_history_all credits at this bank paid ba...      0.055      0.055
# credit_history_critical account                        -0.715     -0.715
# credit_history_delay in paying off in the past           0.37       0.37
# credit_history_existing credits paid back duly ...      0.528      0.528
# credit_history_no credits taken                         0.045      0.045
# purpose_business                                        0.099      0.099
# purpose_car (new)                                       0.224      0.224
# purpose_car (used)                                      0.102      0.102
# purpose_domestic appliances                              0.01       0.01
# purpose_education                                       0.051      0.051
# purpose_furniture/equipment                             0.188      0.188
# purpose_others                                          0.015      0.015
# purpose_radio/television                               -0.722     -0.722
# purpose_repairs                                         0.024      0.024
# purpose_retraining                                      0.109      0.109
# savings_100..500 DM                                     0.112      0.112
# savings_500..1000 DM                                    0.312      0.312
# savings_< 100 DM                                        0.605      0.605
# savings_>= 1000 DM                                      0.048      0.048
# savings_unknown/ no savings account                     -0.83      -0.83
# sex_status_female: divorced/separated/married           0.322      0.322
# sex_status_male: divorced/separated                     0.046      0.046
# sex_status_male: married/widowed                        0.391      0.391
# sex_status_male: single                                -0.465     -0.465
# debtors_co-applicant                                     0.24       0.24
# debtors_guarantor                                       0.052      0.052
# debtors_none                                           -0.094     -0.094
# property_building society savings agreement             0.657      0.657
# property_car or other, not in attribute 6               0.334      0.334
# property_real estate                                   -0.722     -0.722
# property_unknown / no property                          0.155      0.155
# other_installment_plans_bank                            0.149      0.149
# other_installment_plans_none                           -0.195     -0.195
# other_installment_plans_stores                          0.256      0.256
# housing_for free                                        0.417      0.108
# housing_own                                            -0.301      0.158
# housing_rent                                            0.194      0.194
# job_management/self-employed                            0.154      0.154
# job_skilled employee / official                         0.107      0.107
# job_unemployed/unskilled - non-resident                  0.02       0.02
# job_unskilled - resident                                0.204      0.204
# phone_none                                              1.094      1.094
# phone_yes, registered under the customers name         -0.605     -0.605
# foreign_no                                              0.232      0.232
# foreign_yes                                            -0.039     -0.039
# employment_1..4 years                                   0.334      0.334
# employment_4..7 years                                    0.55       0.55
# employment_< 1 year                                     0.171      0.171
# employment_>= 7 years                                  -0.738     -0.738
# employment_unemployed                                    0.06       0.06
#
#                                                    CF4 change CF5 change  \
# number of attributes changed                             16.0       16.0
# duration                                               34.252     34.563
# credit                                               9154.314   9237.602
# installment_percent                                     1.511      1.525
# residence_duration                                      1.511      1.525
# age                                                         -          -
# existing_credits                                       -1.511     -1.525
# people_maintained                                       0.504      0.508
# account_status_0..200 DM                                    -          -
# account_status_< 0 DM                                       -          -
# account_status_>= 200 DM                                    -          -
# account_status_no checking account                          -          -
# credit_history_all credits at this bank paid ba...        1.0        1.0
# credit_history_critical account                          -1.0       -1.0
# credit_history_delay in paying off in the past              -          -
# credit_history_existing credits paid back duly ...          -          -
# credit_history_no credits taken                             -          -
# purpose_business                                            -          -
# purpose_car (new)                                           -          -
# purpose_car (used)                                          -          -
# purpose_domestic appliances                                 -          -
# purpose_education                                         1.0        1.0
# purpose_furniture/equipment                                 -          -
# purpose_others                                              -          -
# purpose_radio/television                                 -1.0       -1.0
# purpose_repairs                                             -          -
# purpose_retraining                                          -          -
# savings_100..500 DM                                       1.0        1.0
# savings_500..1000 DM                                        -          -
# savings_< 100 DM                                            -          -
# savings_>= 1000 DM                                          -          -
# savings_unknown/ no savings account                      -1.0       -1.0
# sex_status_female: divorced/separated/married               -          -
# sex_status_male: divorced/separated                         -          -
# sex_status_male: married/widowed                          1.0        1.0
# sex_status_male: single                                  -1.0       -1.0
# debtors_co-applicant                                        -          -
# debtors_guarantor                                           -          -
# debtors_none                                                -          -
# property_building society savings agreement                 -          -
# property_car or other, not in attribute 6                   -          -
# property_real estate                                     -1.0       -1.0
# property_unknown / no property                            1.0        1.0
# other_installment_plans_bank                                -          -
# other_installment_plans_none                             -1.0       -1.0
# other_installment_plans_stores                            1.0        1.0
# housing_for free                                          1.0        1.0
# housing_own                                              -1.0       -1.0
# housing_rent                                                -          -
# job_management/self-employed                                -          -
# job_skilled employee / official                             -          -
# job_unemployed/unskilled - non-resident                     -          -
# job_unskilled - resident                                    -          -
# phone_none                                                  -          -
# phone_yes, registered under the customers name              -          -
# foreign_no                                                  -          -
# foreign_yes                                                 -          -
# employment_1..4 years                                       -          -
# employment_4..7 years                                       -          -
# employment_< 1 year                                       1.0        1.0
# employment_>= 7 years                                    -1.0       -1.0
# employment_unemployed                                       -          -
#
#                                                    CF6 change CF7 change  \
# number of attributes changed                             13.0       15.0
# duration                                               34.728     35.081
# credit                                               9281.553    9376.01
# installment_percent                                         -      1.548
# residence_duration                                          -      1.548
# age                                                         -          -
# existing_credits                                       -1.532     -1.548
# people_maintained                                           -          -
# account_status_0..200 DM                                    -          -
# account_status_< 0 DM                                       -          -
# account_status_>= 200 DM                                    -          -
# account_status_no checking account                          -          -
# credit_history_all credits at this bank paid ba...        1.0        1.0
# credit_history_critical account                          -1.0       -1.0
# credit_history_delay in paying off in the past              -          -
# credit_history_existing credits paid back duly ...          -          -
# credit_history_no credits taken                             -          -
# purpose_business                                            -          -
# purpose_car (new)                                           -          -
# purpose_car (used)                                          -          -
# purpose_domestic appliances                                 -          -
# purpose_education                                         1.0        1.0
# purpose_furniture/equipment                                 -          -
# purpose_others                                              -          -
# purpose_radio/television                                 -1.0       -1.0
# purpose_repairs                                             -          -
# purpose_retraining                                          -          -
# savings_100..500 DM                                       1.0        1.0
# savings_500..1000 DM                                        -          -
# savings_< 100 DM                                            -          -
# savings_>= 1000 DM                                          -          -
# savings_unknown/ no savings account                      -1.0       -1.0
# sex_status_female: divorced/separated/married               -          -
# sex_status_male: divorced/separated                         -          -
# sex_status_male: married/widowed                          1.0        1.0
# sex_status_male: single                                  -1.0       -1.0
# debtors_co-applicant                                        -          -
# debtors_guarantor                                           -          -
# debtors_none                                                -          -
# property_building society savings agreement                 -          -
# property_car or other, not in attribute 6                   -          -
# property_real estate                                     -1.0       -1.0
# property_unknown / no property                            1.0        1.0
# other_installment_plans_bank                                -          -
# other_installment_plans_none                             -1.0       -1.0
# other_installment_plans_stores                            1.0        1.0
# housing_for free                                          1.0        1.0
# housing_own                                              -1.0       -1.0
# housing_rent                                                -          -
# job_management/self-employed                                -          -
# job_skilled employee / official                             -          -
# job_unemployed/unskilled - non-resident                     -          -
# job_unskilled - resident                                    -          -
# phone_none                                                  -          -
# phone_yes, registered under the customers name              -          -
# foreign_no                                                  -          -
# foreign_yes                                                 -          -
# employment_1..4 years                                       -          -
# employment_4..7 years                                       -          -
# employment_< 1 year                                       1.0        1.0
# employment_>= 7 years                                    -1.0       -1.0
# employment_unemployed                                       -          -
#
#                                                    CF8 change CF9 change  \
# number of attributes changed                             37.0       37.0
# duration                                               38.762    115.735
# credit                                                   -2.3     48.457
# installment_percent                                   105.808    150.227
# residence_duration                                     92.268    169.492
# age                                                         -          -
# existing_credits                                      -39.127    -54.312
# people_maintained                                      60.688     85.674
# account_status_0..200 DM                                0.275      0.275
# account_status_< 0 DM                                  -0.273     -0.721
# account_status_>= 200 DM                                0.068      0.068
# account_status_no checking account                      0.379      0.864
# credit_history_all credits at this bank paid ba...      0.283      0.055
# credit_history_critical account                        -0.715     -0.264
# credit_history_delay in paying off in the past          0.088      0.088
# credit_history_existing credits paid back duly ...      0.528      0.528
# credit_history_no credits taken                         0.045      0.045
# purpose_business                                        0.099      0.099
# purpose_car (new)                                       0.224      0.224
# purpose_car (used)                                      0.102      0.102
# purpose_domestic appliances                              0.01       0.01
# purpose_education                                       0.051      0.051
# purpose_furniture/equipment                             0.188      0.188
# purpose_others                                          0.015      0.015
# purpose_radio/television                               -0.722     -0.722
# purpose_repairs                                         0.024      0.024
# purpose_retraining                                      0.109      0.109
# savings_100..500 DM                                     0.112      0.112
# savings_500..1000 DM                                    0.312      0.312
# savings_< 100 DM                                        0.605      0.605
# savings_>= 1000 DM                                      0.048      0.048
# savings_unknown/ no savings account                     -0.83      -0.83
# sex_status_female: divorced/separated/married           0.322      0.322
# sex_status_male: divorced/separated                     0.046      0.046
# sex_status_male: married/widowed                        0.391      0.391
# sex_status_male: single                                -0.465     -0.465
# debtors_co-applicant                                    0.041      0.041
# debtors_guarantor                                       0.276      0.052
# debtors_none                                           -0.094      0.198
# property_building society savings agreement             0.657      0.657
# property_car or other, not in attribute 6               0.334      0.334
# property_real estate                                   -0.722     -0.722
# property_unknown / no property                          0.155      0.155
# other_installment_plans_bank                            0.149      0.149
# other_installment_plans_none                            0.201      0.201
# other_installment_plans_stores                          0.046      0.046
# housing_for free                                        0.108      0.108
# housing_own                                             0.158      0.158
# housing_rent                                            0.194      0.194
# job_management/self-employed                            0.154      0.514
# job_skilled employee / official                        -0.378     -0.378
# job_unemployed/unskilled - non-resident                  0.16       0.02
# job_unskilled - resident                                0.204      0.204
# phone_none                                              1.094      1.094
# phone_yes, registered under the customers name         -0.605     -0.605
# foreign_no                                              0.232      0.232
# foreign_yes                                            -0.039     -0.039
# employment_1..4 years                                   0.805      0.805
# employment_4..7 years                                   0.172      0.172
# employment_< 1 year                                     0.171      0.171
# employment_>= 7 years                                  -0.738     -0.738
# employment_unemployed                                    0.06       0.06
#
#                                                    CF10 change  \
# number of attributes changed                              37.0
# duration                                               120.868
# credit                                                  46.757
# installment_percent                                    159.691
# residence_duration                                     171.072
# age                                                          -
# existing_credits                                       -55.239
# people_maintained                                       90.019
# account_status_0..200 DM                                 0.275
# account_status_< 0 DM                                   -0.721
# account_status_>= 200 DM                                 0.068
# account_status_no checking account                       0.864
# credit_history_all credits at this bank paid ba...       0.055
# credit_history_critical account                         -0.264
# credit_history_delay in paying off in the past           0.088
# credit_history_existing credits paid back duly ...       0.528
# credit_history_no credits taken                          0.045
# purpose_business                                         0.099
# purpose_car (new)                                        0.641
# purpose_car (used)                                       0.102
# purpose_domestic appliances                               0.01
# purpose_education                                        0.051
# purpose_furniture/equipment                              0.188
# purpose_others                                           0.015
# purpose_radio/television                                -0.722
# purpose_repairs                                          0.024
# purpose_retraining                                        0.01
# savings_100..500 DM                                      0.112
# savings_500..1000 DM                                     0.312
# savings_< 100 DM                                         0.605
# savings_>= 1000 DM                                       0.048
# savings_unknown/ no savings account                      -0.83
# sex_status_female: divorced/separated/married            0.322
# sex_status_male: divorced/separated                      0.046
# sex_status_male: married/widowed                         0.391
# sex_status_male: single                                 -0.465
# debtors_co-applicant                                     0.041
# debtors_guarantor                                        0.052
# debtors_none                                             0.198
# property_building society savings agreement              0.657
# property_car or other, not in attribute 6                0.334
# property_real estate                                    -0.722
# property_unknown / no property                           0.155
# other_installment_plans_bank                             0.149
# other_installment_plans_none                             0.201
# other_installment_plans_stores                           0.046
# housing_for free                                         0.108
# housing_own                                              0.158
# housing_rent                                             0.194
# job_management/self-employed                             0.154
# job_skilled employee / official                         -0.378
# job_unemployed/unskilled - non-resident                   0.16
# job_unskilled - resident                                 0.204
# phone_none                                               1.094
# phone_yes, registered under the customers name          -0.605
# foreign_no                                               0.232
# foreign_yes                                             -0.039
# employment_1..4 years                                    0.805
# employment_4..7 years                                    0.172
# employment_< 1 year                                      0.171
# employment_>= 7 years                                   -0.738
# employment_unemployed                                     0.06
#
#                                                                  constraint
# number of attributes changed
# duration
# credit
# installment_percent
# residence_duration
# age                                                 Monotonicity increasing
# existing_credits
# people_maintained
# account_status_0..200 DM                                             OneHot
# account_status_< 0 DM                                                OneHot
# account_status_>= 200 DM                                             OneHot
# account_status_no checking account                                   OneHot
# credit_history_all credits at this bank paid ba...                   OneHot
# credit_history_critical account                                      OneHot
# credit_history_delay in paying off in the past                       OneHot
# credit_history_existing credits paid back duly ...                   OneHot
# credit_history_no credits taken                                      OneHot
# purpose_business                                                     OneHot
# purpose_car (new)                                                    OneHot
# purpose_car (used)                                                   OneHot
# purpose_domestic appliances                                          OneHot
# purpose_education                                                    OneHot
# purpose_furniture/equipment                                          OneHot
# purpose_others                                                       OneHot
# purpose_radio/television                                             OneHot
# purpose_repairs                                                      OneHot
# purpose_retraining                                                   OneHot
# savings_100..500 DM                                                  OneHot
# savings_500..1000 DM                                                 OneHot
# savings_< 100 DM                                                     OneHot
# savings_>= 1000 DM                                                   OneHot
# savings_unknown/ no savings account                                  OneHot
# sex_status_female: divorced/separated/married                        OneHot
# sex_status_male: divorced/separated                                  OneHot
# sex_status_male: married/widowed                                     OneHot
# sex_status_male: single                                              OneHot
# debtors_co-applicant                                                 OneHot
# debtors_guarantor                                                    OneHot
# debtors_none                                                         OneHot
# property_building society savings agreement                          OneHot
# property_car or other, not in attribute 6                            OneHot
# property_real estate                                                 OneHot
# property_unknown / no property                                       OneHot
# other_installment_plans_bank                                         OneHot
# other_installment_plans_none                                         OneHot
# other_installment_plans_stores                                       OneHot
# housing_for free                                                     OneHot
# housing_own                                                          OneHot
# housing_rent                                                         OneHot
# job_management/self-employed                                         OneHot
# job_skilled employee / official                                      OneHot
# job_unemployed/unskilled - non-resident                              OneHot
# job_unskilled - resident                                             OneHot
# phone_none                                                           OneHot
# phone_yes, registered under the customers name                       OneHot
# foreign_no                                                           OneHot
# foreign_yes                                                          OneHot
# employment_1..4 years                                                OneHot
# employment_4..7 years                                                OneHot
# employment_< 1 year                                                  OneHot
# employment_>= 7 years                                                OneHot
# employment_unemployed                                                OneHot

# %%
compare(X_test, cfs, constraints=constraints)
# Out:
#                                                          X CF1 change  \
# number of attributes changed                           0.0       13.0
# duration                                               6.0     34.728
# credit                                              1169.0   9281.553
# installment_percent                                    4.0          -
# residence_duration                                     4.0          -
# age                                                   67.0          -
# existing_credits                                       2.0     -1.532
# people_maintained                                      1.0          -
# account_status_0..200 DM                               0.0          -
# account_status_< 0 DM                                  1.0          -
# account_status_>= 200 DM                               0.0          -
# account_status_no checking account                     0.0          -
# credit_history_all credits at this bank paid ba...     0.0        1.0
# credit_history_critical account                        1.0       -1.0
# credit_history_delay in paying off in the past         0.0          -
# credit_history_existing credits paid back duly ...     0.0          -
# credit_history_no credits taken                        0.0          -
# purpose_business                                       0.0          -
# purpose_car (new)                                      0.0          -
# purpose_car (used)                                     0.0          -
# purpose_domestic appliances                            0.0          -
# purpose_education                                      0.0        1.0
# purpose_furniture/equipment                            0.0          -
# purpose_others                                         0.0          -
# purpose_radio/television                               1.0       -1.0
# purpose_repairs                                        0.0          -
# purpose_retraining                                     0.0          -
# savings_100..500 DM                                    0.0        1.0
# savings_500..1000 DM                                   0.0          -
# savings_< 100 DM                                       0.0          -
# savings_>= 1000 DM                                     0.0          -
# savings_unknown/ no savings account                    1.0       -1.0
# sex_status_female: divorced/separated/married          0.0          -
# sex_status_male: divorced/separated                    0.0          -
# sex_status_male: married/widowed                       0.0        1.0
# sex_status_male: single                                1.0       -1.0
# debtors_co-applicant                                   0.0          -
# debtors_guarantor                                      0.0          -
# debtors_none                                           1.0          -
# property_building society savings agreement            0.0          -
# property_car or other, not in attribute 6              0.0          -
# property_real estate                                   1.0       -1.0
# property_unknown / no property                         0.0        1.0
# other_installment_plans_bank                           0.0          -
# other_installment_plans_none                           1.0       -1.0
# other_installment_plans_stores                         0.0        1.0
# housing_for free                                       0.0        1.0
# housing_own                                            1.0       -1.0
# housing_rent                                           0.0          -
# job_management/self-employed                           0.0          -
# job_skilled employee / official                        1.0          -
# job_unemployed/unskilled - non-resident                0.0          -
# job_unskilled - resident                               0.0          -
# phone_none                                             0.0          -
# phone_yes, registered under the customers name         1.0          -
# foreign_no                                             0.0          -
# foreign_yes                                            1.0          -
# employment_1..4 years                                  0.0          -
# employment_4..7 years                                  0.0          -
# employment_< 1 year                                    0.0        1.0
# employment_>= 7 years                                  1.0       -1.0
# employment_unemployed                                  0.0          -
#
#                                                    CF2 change  \
# number of attributes changed                             15.0
# duration                                               35.081
# credit                                                9376.01
# installment_percent                                     1.548
# residence_duration                                      1.548
# age                                                         -
# existing_credits                                       -1.548
# people_maintained                                           -
# account_status_0..200 DM                                    -
# account_status_< 0 DM                                       -
# account_status_>= 200 DM                                    -
# account_status_no checking account                          -
# credit_history_all credits at this bank paid ba...        1.0
# credit_history_critical account                          -1.0
# credit_history_delay in paying off in the past              -
# credit_history_existing credits paid back duly ...          -
# credit_history_no credits taken                             -
# purpose_business                                            -
# purpose_car (new)                                           -
# purpose_car (used)                                          -
# purpose_domestic appliances                                 -
# purpose_education                                         1.0
# purpose_furniture/equipment                                 -
# purpose_others                                              -
# purpose_radio/television                                 -1.0
# purpose_repairs                                             -
# purpose_retraining                                          -
# savings_100..500 DM                                       1.0
# savings_500..1000 DM                                        -
# savings_< 100 DM                                            -
# savings_>= 1000 DM                                          -
# savings_unknown/ no savings account                      -1.0
# sex_status_female: divorced/separated/married               -
# sex_status_male: divorced/separated                         -
# sex_status_male: married/widowed                          1.0
# sex_status_male: single                                  -1.0
# debtors_co-applicant                                        -
# debtors_guarantor                                           -
# debtors_none                                                -
# property_building society savings agreement                 -
# property_car or other, not in attribute 6                   -
# property_real estate                                     -1.0
# property_unknown / no property                            1.0
# other_installment_plans_bank                                -
# other_installment_plans_none                             -1.0
# other_installment_plans_stores                            1.0
# housing_for free                                          1.0
# housing_own                                              -1.0
# housing_rent                                                -
# job_management/self-employed                                -
# job_skilled employee / official                             -
# job_unemployed/unskilled - non-resident                     -
# job_unskilled - resident                                    -
# phone_none                                                  -
# phone_yes, registered under the customers name              -
# foreign_no                                                  -
# foreign_yes                                                 -
# employment_1..4 years                                       -
# employment_4..7 years                                       -
# employment_< 1 year                                       1.0
# employment_>= 7 years                                    -1.0
# employment_unemployed                                       -
#
#                                                                  constraint
# number of attributes changed
# duration
# credit
# installment_percent
# residence_duration
# age                                                 Monotonicity increasing
# existing_credits
# people_maintained
# account_status_0..200 DM                                             OneHot
# account_status_< 0 DM                                                OneHot
# account_status_>= 200 DM                                             OneHot
# account_status_no checking account                                   OneHot
# credit_history_all credits at this bank paid ba...                   OneHot
# credit_history_critical account                                      OneHot
# credit_history_delay in paying off in the past                       OneHot
# credit_history_existing credits paid back duly ...                   OneHot
# credit_history_no credits taken                                      OneHot
# purpose_business                                                     OneHot
# purpose_car (new)                                                    OneHot
# purpose_car (used)                                                   OneHot
# purpose_domestic appliances                                          OneHot
# purpose_education                                                    OneHot
# purpose_furniture/equipment                                          OneHot
# purpose_others                                                       OneHot
# purpose_radio/television                                             OneHot
# purpose_repairs                                                      OneHot
# purpose_retraining                                                   OneHot
# savings_100..500 DM                                                  OneHot
# savings_500..1000 DM                                                 OneHot
# savings_< 100 DM                                                     OneHot
# savings_>= 1000 DM                                                   OneHot
# savings_unknown/ no savings account                                  OneHot
# sex_status_female: divorced/separated/married                        OneHot
# sex_status_male: divorced/separated                                  OneHot
# sex_status_male: married/widowed                                     OneHot
# sex_status_male: single                                              OneHot
# debtors_co-applicant                                                 OneHot
# debtors_guarantor                                                    OneHot
# debtors_none                                                         OneHot
# property_building society savings agreement                          OneHot
# property_car or other, not in attribute 6                            OneHot
# property_real estate                                                 OneHot
# property_unknown / no property                                       OneHot
# other_installment_plans_bank                                         OneHot
# other_installment_plans_none                                         OneHot
# other_installment_plans_stores                                       OneHot
# housing_for free                                                     OneHot
# housing_own                                                          OneHot
# housing_rent                                                         OneHot
# job_management/self-employed                                         OneHot
# job_skilled employee / official                                      OneHot
# job_unemployed/unskilled - non-resident                              OneHot
# job_unskilled - resident                                             OneHot
# phone_none                                                           OneHot
# phone_yes, registered under the customers name                       OneHot
# foreign_no                                                           OneHot
# foreign_yes                                                          OneHot
# employment_1..4 years                                                OneHot
# employment_4..7 years                                                OneHot
# employment_< 1 year                                                  OneHot
# employment_>= 7 years                                                OneHot
# employment_unemployed                                                OneHot

# %% [markdown]
# For more information on the library, see our documentation: https://counterfactuals.readthedocs.io/en/latest/
